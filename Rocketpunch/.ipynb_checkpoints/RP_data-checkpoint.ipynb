# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import time

chromedriver = "./chromedriver.exe"
url = "https://www.rocketpunch.com/jobs?job=1"
data = pd.read_csv("./RP_TechStack.csv")
data_arr = []

options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-logging"])
driver = webdriver.Chrome(chromedriver, options=options)

driver.get(url)
time.sleep(3)

page_num = driver.find_element(By.CLASS_NAME, 'tablet.computer.large.screen.widescreen.only')
page_num = page_num.find_elements(By.CLASS_NAME, 'item')[-1].text
for i in range(1, int(page_num)):
    driver.get(url+"&page="+str(i))
    time.sleep(1)
    recruitments = driver.find_elements(By.CLASS_NAME, 'nowrap.job-title.primary.link')
    recruitment_url = []
    for recruitment in recruitments:
        recruitment_url.append(recruitment.get_attribute('href'))
    for rec_url in recruitment_url:
        driver.get(rec_url)
        tmp_arr = []
        tmp_arr.append(rec_url[33:38])
        tmp_arr.append(driver.find_element(By.CLASS_NAME, "nowrap.job-title").text)
        tech_stack_area = driver.find_element(By.CLASS_NAME, "job-specialties")
        tech_stack = tech_stack_area.find_elements(By.CLASS_NAME, "ui.circular.basic.label")
        for tech in tech_stack:
            tech = tech.text
            tmp_arr.append(tech)
        data_arr.append(tmp_arr)
        print(pd.DataFrame(data_arr))
# Out:
#        0                  1                                         2     3  \
# 0  86735  프론트엔드 (웹)개발자 채용공고  웹 프론트엔드 개발(HTML5/CSS3/JavaScript/Vue.js)  웹서비스
#
#           4         5      6          7    8
# 0  프론트엔드 개발  프론트엔드개발자  프론트엔드  웹프론트엔드 개발  웹개발
#       0                                  1   \
# 0  86735                  프론트엔드 (웹)개발자 채용공고
# 1  88879  [연봉 인상 최대 30%] App 모바일 앱 개발자 (경력)
#
#                                          2        3          4         5   \
# 0  웹 프론트엔드 개발(HTML5/CSS3/JavaScript/Vue.js)     웹서비스   프론트엔드 개발  프론트엔드개발자
# 1                                       Git  Android  안드로이드 앱개발       iOS
#
#         6          7        8              9       10      11          12
# 0    프론트엔드  웹프론트엔드 개발      웹개발           None    None    None        None
# 1  ios 앱개발  어플리케이션 개발  Flutter  native app 개발  아이폰개발자  모바일앱개발  Android앱개발
#       0                                    1   \
# 0  86735                    프론트엔드 (웹)개발자 채용공고
# ...
